# %%
import pandas as pd 
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Read in dataset
covid_trials_df = pd.read_csv("SearchResults.tsv", sep="\t")

# %%
columns_of_interest = ['NCT Number', 
                       'Title', 
                       'Locations',
                       'Status', 
                       'Study Results',
                       'Conditions', 
                       'Interventions', 
                       'Outcome Measures', 
                       'Sponsor/Collaborators', 
                       'Gender', 
                       'Age', 
                       'Phases', 
                       'Enrollment',
                       'Funded Bys', 
                       'Study Type', 
                       'Study Designs',
                       'Start Date',
                       'Completion Date',
                       'First Posted',
                       'Last Update Posted',
                       'URL']
covid_trials_df = covid_trials_df[columns_of_interest]

# %%
date_columns = ['Start Date',                       
                'Completion Date',
                'First Posted',
                'Last Update Posted' ]
for d in date_columns:
    # Only keep month and year
    covid_trials_df[d] = [(str(i).split(" ")[0] + " " + str(i).split(" ")[-1]) for i in list(covid_trials_df[d])]

# %%
# Add a countries column
covid_trials_df.loc[:,"Location_Country"] = [str(i).split(",")[-1].strip() for i in list(covid_trials_df["Locations"].copy())]
# fix Incorrectly named country columns 
covid_trials_df["Location_Country"].loc[covid_trials_df["Location_Country"] == "Islamic Republic of"] = "Iran"
covid_trials_df["Location_Country"].loc[covid_trials_df["Location_Country"] == "The Democratic Republic of the"] = "Congo"
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
# Add a countries column
covid_trials_df.loc[:,"Location_City_or_State"] = [str(i).split(",")[-2].strip() 
                                                   if len(str(i).split(",")) > 1 
                                                   else str(i)
                                                   for i in list(covid_trials_df["Locations"].copy())]

# %%
covid_trials_df.loc[:,"Location_Institution"] = [str(i).split(",")[0].strip()  
                                                   for i in list(covid_trials_df["Locations"].copy())]

# %% [markdown]
# # cols_to_explode

# %%
# cols_to_explode = ["Interventions", 
#                    "Outcome Measures", 
#                    "Sponsor/Collaborators",
#                    "Funded Bys",
#                    "Study Type",
#                    "Study Designs"]

# cols_not_to_explode = [i for i in list(covid_trials_df.columns) if i not in cols_to_explode]

# # Convert columns with multiple fields into lists so they can be exploded 
# for lst_col in cols_to_explode: 
#     print(lst_col)
#     # split by delimiter
#     covid_trials_df = covid_trials_df.assign(**{lst_col:covid_trials_df[lst_col].str.split('|')})
    
#     # explode delimited column
#     covid_trials_df = covid_trials_df.explode(lst_col)
# Out:
# Interventions
# Outcome Measures
# Sponsor/Collaborators
# Funded Bys
# Study Type
# Study Designs

# %%
covid_trials_df = covid_trials_df.applymap(lambda s:s.upper() if type(s) == str else s)
covid_trials_df = covid_trials_df.replace("nan", np.nan)
covid_trials_df = covid_trials_df.replace("NaN", np.nan)

# %%
study_designs = covid_trials_df[['NCT Number', 'Study Designs']].drop_duplicates() # pk: NCT number
interventions = covid_trials_df[['NCT Number', 'Interventions']].drop_duplicates() # pk: NCT number

# %%
outcome_measures = covid_trials_df[['NCT Number', 'Outcome Measures']].drop_duplicates() # pk: index
sponsor_collaborators = covid_trials_df[['NCT Number', 'Sponsor/Collaborators']].drop_duplicates() # pk: index
funded_bys = covid_trials_df[['NCT Number', 'Funded Bys']].drop_duplicates() # pk: index
study_type = covid_trials_df[['NCT Number', 'Study Type']].drop_duplicates() # pk: index

# %%
trial_into_list = ['NCT Number', 'Title', 'Locations', 'Status', 'Study Results', 'Conditions',
                   'Gender', 'Age', 'Phases','Enrollment', 'URL', 'Location_Country', 'Location_City_or_State',
                   'Location_Institution', 'Start Date', 'Completion Date', 'First Posted','Last Update Posted']
trial_info = covid_trials_df[trial_into_list].drop_duplicates()

# %% [markdown]
# # Study Design

# %%
study_design_list = ["ALLOCATION", 
                     "INTERVENTION MODEL", 
                     "MASKING",
                     "PRIMARY PURPOSE",
                     "OBSERVATIONAL MODEL",
                     "TIME PERSPECTIVE"] 
def parse_study_design(row):
    dic = {}
    for i in range(len(study_design_list)):
        dic[study_design_list[i]] = 'nan'
    try:
        row = row.split("|")
        for item in row:
            item = item.split(":")
            key = item[0].strip()
            value = item[1].strip()
            if key in dic:
                dic[key] = value
        return dic
    except:
        return dic
study_design_df = study_designs['Study Designs'].apply(parse_study_design)
study_designs.loc[:,study_design_list] = pd.json_normalize(study_design_df)

# %%
study_designs.drop('Study Designs', axis=1, inplace=True)

# %%
study_designs = study_designs.replace("nan", np.nan)
study_designs = study_designs.replace("N/A", np.nan)
study_designs.head()
# Out:
#     NCT Number  ALLOCATION       INTERVENTION MODEL  \
# 0  NCT04372602  RANDOMIZED  SINGLE GROUP ASSIGNMENT
# 1  NCT04364698         NaN                      NaN
# 2  NCT04482621  RANDOMIZED      PARALLEL ASSIGNMENT
# 3  NCT04459637         NaN                      NaN
# 4  NCT04425538         NaN  SINGLE GROUP ASSIGNMENT
#
#                                              MASKING PRIMARY PURPOSE  \
# 0  TRIPLE (PARTICIPANT, CARE PROVIDER, INVESTIGATOR)       TREATMENT
# 1                                                NaN             NaN
# 2                 DOUBLE (PARTICIPANT, INVESTIGATOR)       TREATMENT
# 3                                                NaN             NaN
# 4                                  NONE (OPEN LABEL)       TREATMENT
#
#   OBSERVATIONAL MODEL TIME PERSPECTIVE
# 0                 NaN              NaN
# 1              COHORT      PROSPECTIVE
# 2                 NaN              NaN
# 3              COHORT      PROSPECTIVE
# 4                 NaN              NaN

# %% [markdown]
# # Interventions

# %%
intervention_list = ['DRUG', 'PROCEDURE', 'OTHER', 'DEVICE', 'BIOLOGICAL', 'DIAGNOSTIC TEST',
                     'DIETARY SUPPLEMENT', 'GENETIC', 'COMBINATION PRODUCT', 'BEHAVIORAL', 'RADIATION'] 
def parse_intervention(row):
    dic = {}
    for i in range(len(intervention_list)):
        dic[intervention_list[i]] = 'nan'
    try:
        row = row.split("|")
        for item in row:
            item = item.split(":")
            key = item[0].strip()
            value = item[1].strip()
            if key in dic:
                dic[key] = value
        return dic
    except:
        return dic
intervention_df = interventions['Interventions'].apply(parse_intervention)
interventions.loc[:,intervention_list] = pd.json_normalize(intervention_df)

# %%
interventions.drop('Interventions', axis=1, inplace=True)

# %%
interventions = interventions.replace("nan", np.nan)
interventions = interventions.replace("N/A", np.nan)
interventions.head()
# Out:
#     NCT Number        DRUG              PROCEDURE           OTHER DEVICE  \
# 0  NCT04372602     PLACEBO  PERIPHERAL BLOOD DRAW             NaN    NaN
# 1  NCT04364698         NaN                    NaN             NaN    NaN
# 2  NCT04482621  DECITABINE                    NaN  PLACEBO SALINE    NaN
# 3  NCT04459637         NaN                    NaN             NaN    NaN
# 4  NCT04425538  INFLIXIMAB                    NaN             NaN    NaN
#
#   BIOLOGICAL DIAGNOSTIC TEST DIETARY SUPPLEMENT GENETIC COMBINATION PRODUCT  \
# 0        NaN             NaN                NaN     NaN                 NaN
# 1        NaN             NaN                NaN     NaN                 NaN
# 2        NaN             NaN                NaN     NaN                 NaN
# 3        NaN             NaN                NaN     NaN                 NaN
# 4        NaN             NaN                NaN     NaN                 NaN
#
#   BEHAVIORAL RADIATION
# 0        NaN       NaN
# 1        NaN       NaN
# 2        NaN       NaN
# 3        NaN       NaN
# 4        NaN       NaN

# %%
covid_trials_df.head(10)
# Out:
#     NCT Number                                              Title  \
# 0  NCT04372602                       DUVELISIB TO COMBAT COVID-19
# 1  NCT04364698  OBSERVATIONAL COHORT OF COVID-19 PATIENTS AT R...
# 2  NCT04482621  DECITABINE FOR CORONAVIRUS (COVID-19) PNEUMONI...
# 3  NCT04459637  COVID-19 SURVEILLANCE BASED ON SMART WEARABLE ...
# 4  NCT04425538  A PHASE 2 TRIAL OF INFLIXIMAB IN CORONAVIRUS D...
# 5  NCT04547257  SAFETY & PERFORMANCE EVALUATION OF SERAPH 100 ...
# 6  NCT04454307  SAFETY AND EFFICACY OF TRAMADOL IN COVID-19 EG...
# 7  NCT04452435  SAFETY AND EFFICACY OF C21 IN SUBJECTS WITH CO...
# 8  NCT04333550          APPLICATION OF DESFERAL TO TREAT COVID-19
# 9  NCT04432987        DORNASE ALPHA FOR THE TREATMENT OF COVID-19
#
#                                            Locations              Status  \
# 0  WASHINGTON UNIVERSITY SCHOOL OF MEDICINE, SAIN...  NOT YET RECRUITING
# 1  DEPARTMENT OF INFECTIOLOGY, RAYMOND POINCARÉ H...          RECRUITING
# 2  JOHNS HOPKINS UNIVERSITY, BALTIMORE, MARYLAND,...          RECRUITING
# 3  PEKING UNIVERSITY FIRST HOSPITAL, BEIJING, BEI...  NOT YET RECRUITING
# 4  TUFTS MEDICAL CENTER, BOSTON, MASSACHUSETTS, U...          RECRUITING
# 5     JENS SCHIRRMACHER, VAALS, LIMBURG, NETHERLANDS  NOT YET RECRUITING
# 6                                                NaN  NOT YET RECRUITING
# 7  DEPARTMENT OF MEDICINE, CIVIL HOSPITAL AND B J...          RECRUITING
# 8  REGENERATIVE MEDICINE RESEARCH CENTER, KERMANS...          RECRUITING
# 9     ACIBADEM ALTUNIZADE HOSPITAL, ISTANBUL, TURKEY          RECRUITING
#
#           Study Results Conditions  \
# 0  NO RESULTS AVAILABLE   COVID-19
# 1  NO RESULTS AVAILABLE   COVID-19
# 2  NO RESULTS AVAILABLE   COVID-19
# 3  NO RESULTS AVAILABLE   COVID-19
# 4  NO RESULTS AVAILABLE   COVID-19
# 5  NO RESULTS AVAILABLE   COVID-19
# 6  NO RESULTS AVAILABLE   COVID-19
# 7  NO RESULTS AVAILABLE   COVID-19
# 8  NO RESULTS AVAILABLE   COVID-19
# 9  NO RESULTS AVAILABLE   COVID-19
#
#                                        Interventions  \
# 0  DRUG: DUVELISIB|PROCEDURE: PERIPHERAL BLOOD DR...
# 1                                                NaN
# 2             DRUG: DECITABINE|OTHER: PLACEBO SALINE
# 3                                                NaN
# 4                                   DRUG: INFLIXIMAB
# 5                                 DEVICE: SERAPH 100
# 6  DRUG: TRAMADOL|OTHER: STANDARD CARE DELIVERED ...
# 7                            DRUG: C21|DRUG: PLACEBO
# 8                                 DRUG: DEFEROXAMINE
# 9                                    DRUG: PULMOZYME
#
#                                     Outcome Measures  \
# 0  OVERALL SURVIVAL|LENGTH OF HOSPITAL STAY|LENGT...
# 1  CLINICAL, BIOLOGICAL AND RADIOLOGICAL CHARACTE...
# 2  CHANGE IN CLINICAL STATE AS ASSESSED BY A 6-PO...
# 3  DETERIORATION OF THE CONDITION|MORTALITY|THE I...
# 4  TIME TO IMPROVEMENT IN OXYGENATION|28-DAY MORT...
# 5  CHANGE IN ORGAN FAILURE|CHANGE IN ORGAN FAILUR...
# 6              NUMBER OF COVID-19 PCR NEGATIVE CASES
# 7  CHANGE FROM BASELINE IN C-REACTIVE PROTEIN (CR...
# 8  MORTALITY RATE|CHANGE IN PATIENTS CLINICAL MAN...
# 9                                  RESPONSE|SURVIVAL
#
#                                Sponsor/Collaborators Gender  \
# 0  WASHINGTON UNIVERSITY SCHOOL OF MEDICINE|VERAS...    ALL
# 1            ASSISTANCE PUBLIQUE - HÔPITAUX DE PARIS    ALL
# 2                           JOHNS HOPKINS UNIVERSITY    ALL
# 3                   PEKING UNIVERSITY FIRST HOSPITAL    ALL
# 4  TUFTS MEDICAL CENTER|NATIONAL INSTITUTES OF HE...    ALL
# 5  EXTHERA MEDICAL EUROPE BV|EXTHERA MEDICAL CORP...    ALL
# 6                                   TANTA UNIVERSITY    ALL
# 7                      VICORE PHARMA AB|ORPHAN REACH    ALL
# 8          KERMANSHAH UNIVERSITY OF MEDICAL SCIENCES    ALL
# 9  ACIBADEM UNIVERSITY|THE SCIENTIFIC AND TECHNOL...    ALL
#
#                                                  Age           Phases  \
# 0          18 YEARS AND OLDER   (ADULT, OLDER ADULT)          PHASE 2
# 1          18 YEARS AND OLDER   (ADULT, OLDER ADULT)              NaN
# 2          18 YEARS AND OLDER   (ADULT, OLDER ADULT)          PHASE 2
# 3        18 YEARS TO 75 YEARS   (ADULT, OLDER ADULT)              NaN
# 4          18 YEARS AND OLDER   (ADULT, OLDER ADULT)          PHASE 2
# 5        18 YEARS TO 90 YEARS   (ADULT, OLDER ADULT)   NOT APPLICABLE
# 6        18 YEARS TO 65 YEARS   (ADULT, OLDER ADULT)  PHASE 1|PHASE 2
# 7        18 YEARS TO 70 YEARS   (ADULT, OLDER ADULT)          PHASE 2
# 8  3 YEARS TO 99 YEARS   (CHILD, ADULT, OLDER ADULT)  PHASE 1|PHASE 2
# 9          18 YEARS AND OLDER   (ADULT, OLDER ADULT)          PHASE 2
#
#    Enrollment      Funded Bys      Study Type  \
# 0        28.0  OTHER|INDUSTRY  INTERVENTIONAL
# 1       500.0           OTHER   OBSERVATIONAL
# 2        40.0           OTHER  INTERVENTIONAL
# 3       200.0           OTHER   OBSERVATIONAL
# 4        17.0       OTHER|NIH  INTERVENTIONAL
# 5        42.0        INDUSTRY  INTERVENTIONAL
# 6       100.0           OTHER  INTERVENTIONAL
# 7       100.0  INDUSTRY|OTHER  INTERVENTIONAL
# 8        50.0           OTHER  INTERVENTIONAL
# 9        60.0           OTHER  INTERVENTIONAL
#
#                                        Study Designs      Start Date  \
# 0  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: SIN...  SEPTEMBER 2020
# 1  OBSERVATIONAL MODEL: COHORT|TIME PERSPECTIVE: ...        MAY 2020
# 2  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...     AUGUST 2020
# 3  OBSERVATIONAL MODEL: COHORT|TIME PERSPECTIVE: ...       JULY 2020
# 4  ALLOCATION: N/A|INTERVENTION MODEL: SINGLE GRO...       JUNE 2020
# 5  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...    OCTOBER 2020
# 6  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...       JULY 2020
# 7  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...       JULY 2020
# 8  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...      APRIL 2020
# 9  ALLOCATION: RANDOMIZED|INTERVENTION MODEL: PAR...        MAY 2020
#
#   Completion Date    First Posted Last Update Posted  \
# 0      MARCH 2022        MAY 2020     SEPTEMBER 2020
# 1       JUNE 2020      APRIL 2020           MAY 2020
# 2       JULY 2021       JULY 2020        AUGUST 2020
# 3      MARCH 2021       JULY 2020          JULY 2020
# 4   DECEMBER 2020       JUNE 2020          JUNE 2020
# 5      APRIL 2021  SEPTEMBER 2020     SEPTEMBER 2020
# 6    OCTOBER 2020       JULY 2020          JULY 2020
# 7  SEPTEMBER 2021       JUNE 2020     SEPTEMBER 2020
# 8      MARCH 2021      APRIL 2020           MAY 2020
# 9  SEPTEMBER 2020       JUNE 2020          JUNE 2020
#
#                                            URL Location_Country  \
# 0  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04372602    UNITED STATES
# 1  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04364698           FRANCE
# 2  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04482621    UNITED STATES
# 3  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04459637            CHINA
# 4  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04425538    UNITED STATES
# 5  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04547257      NETHERLANDS
# 6  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04454307              NAN
# 7  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04452435   UNITED KINGDOM
# 8  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04333550             IRAN
# 9  HTTPS://CLINICALTRIALS.GOV/SHOW/NCT04432987           TURKEY
#
#   Location_City_or_State                      Location_Institution
# 0               MISSOURI  WASHINGTON UNIVERSITY SCHOOL OF MEDICINE
# 1                GARCHES                DEPARTMENT OF INFECTIOLOGY
# 2               MARYLAND                  JOHNS HOPKINS UNIVERSITY
# 3                BEIJING          PEKING UNIVERSITY FIRST HOSPITAL
# 4          MASSACHUSETTS                      TUFTS MEDICAL CENTER
# 5                LIMBURG                         JENS SCHIRRMACHER
# 6                    NAN                                       NAN
# 7                 LONDON                    DEPARTMENT OF MEDICINE
# 8                   IRAN     REGENERATIVE MEDICINE RESEARCH CENTER
# 9               ISTANBUL              ACIBADEM ALTUNIZADE HOSPITAL

# %% [markdown]
# # Creating a SQLite3 schema following 3NF

# %%
def checkPK(df, pk):
    if np.any(df[pk].isnull()):
        print('NULL values.')
    elif df[pk].drop_duplicates().shape[0] != df.shape[0]:
        print('Duplication.')
    else:
        print('Valid PK.')

# %%
checkPK(covid_trials_df, 'NCT Number')
# Out:
# Valid PK.

# %%
import sqlite3
conn = sqlite3.connect('covid_trials.sqlite')

# %% [markdown]
# ## tables: study_designs, interventions, outcome_measures, sponsor_collaborators, funded_bys, study_type, trial_info

# %%
outcome_measures = covid_trials_df[['NCT Number', 'Outcome Measures']].drop_duplicates() # pk: index
sponsor_collaborators = covid_trials_df[['NCT Number', 'Sponsor/Collaborators']].drop_duplicates() # pk: index
funded_bys = covid_trials_df[['NCT Number', 'Funded Bys']].drop_duplicates() # pk: index
study_type = covid_trials_df[['NCT Number', 'Study Type']].drop_duplicates() # pk: index

# %%
outcome_measures = outcome_measures.assign(**{'Outcome Measures':outcome_measures['Outcome Measures'].str.split('|')})
outcome_measures = outcome_measures.explode('Outcome Measures')
sponsor_collaborators = sponsor_collaborators.assign(**{'Sponsor/Collaborators':sponsor_collaborators['Sponsor/Collaborators'].str.split('|')})
sponsor_collaborators = sponsor_collaborators.explode('Sponsor/Collaborators')
funded_bys = funded_bys.assign(**{'Funded Bys':funded_bys['Funded Bys'].str.split('|')})
funded_bys = funded_bys.explode('Funded Bys')
study_type = study_type.assign(**{'Study Type':study_type['Study Type'].str.split('|')})
study_type = study_type.explode('Study Type')

# %%
outcome_measures.reset_index(drop=True, inplace=True)
outcome_measures['index'] = outcome_measures.index
outcome_measures.head()
# Out:
#     NCT Number              Outcome Measures  index
# 0  NCT04372602              OVERALL SURVIVAL      0
# 1  NCT04372602       LENGTH OF HOSPITAL STAY      1
# 2  NCT04372602            LENGTH OF ICU STAY      2
# 3  NCT04372602    DURATION OF VENTILATOR USE      3
# 4  NCT04372602  DURATION OF VASOPRESSORS USE      4

# %%
sponsor_collaborators.reset_index(drop=True, inplace=True)
sponsor_collaborators['index'] = sponsor_collaborators.index
sponsor_collaborators.head()
# Out:
#     NCT Number                     Sponsor/Collaborators  index
# 0  NCT04372602  WASHINGTON UNIVERSITY SCHOOL OF MEDICINE      0
# 1  NCT04372602                            VERASTEM, INC.      1
# 2  NCT04364698   ASSISTANCE PUBLIQUE - HÔPITAUX DE PARIS      2
# 3  NCT04482621                  JOHNS HOPKINS UNIVERSITY      3
# 4  NCT04459637          PEKING UNIVERSITY FIRST HOSPITAL      4

# %%
funded_bys.reset_index(drop=True, inplace=True)
funded_bys['index'] = funded_bys.index
funded_bys.head()
# Out:
#     NCT Number Funded Bys  index
# 0  NCT04372602      OTHER      0
# 1  NCT04372602   INDUSTRY      1
# 2  NCT04364698      OTHER      2
# 3  NCT04482621      OTHER      3
# 4  NCT04459637      OTHER      4

# %%
study_type.reset_index(drop=True, inplace=True)
study_type['index'] = study_type.index
study_type.head()
# Out:
#     NCT Number      Study Type  index
# 0  NCT04372602  INTERVENTIONAL      0
# 1  NCT04364698   OBSERVATIONAL      1
# 2  NCT04482621  INTERVENTIONAL      2
# 3  NCT04459637   OBSERVATIONAL      3
# 4  NCT04425538  INTERVENTIONAL      4

# %%
study_designs.to_sql('study_designs', conn, if_exists='replace', index=False)
interventions.to_sql('interventions', conn, if_exists='replace', index=False)
trial_info.to_sql('trial_info', conn, if_exists='replace', index=False)
outcome_measures.to_sql('outcome_measures', conn, if_exists='replace', index=False)
sponsor_collaborators.to_sql('sponsor_collaborators', conn, if_exists='replace', index=False)
funded_bys.to_sql('funded_bys', conn, if_exists='replace', index=False)
study_type.to_sql('study_type', conn, if_exists='replace', index=False)
